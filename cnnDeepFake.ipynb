# %%
import os
import pandas as pd

# Obtener la lista de nombres de archivo
filenames = os.listdir('./dataset_fake_real')

# Crear listas para los nombres de archivo y las categorías
categories = []

# Determinar la categoría de cada archivo
for filename in filenames:
    category = filename.split('_')[0]
    if category == 'fake':
        categories.append('fake')
    else:
        categories.append('real')

# Crear el DataFrame completo
fake_real = pd.DataFrame({'filename': filenames, 'category': categories})

# Filtrar 100 imágenes de cada categoría
fake_sample = fake_real[fake_real['category'] == 'fake'].sample(n=500, random_state=42)
real_sample = fake_real[fake_real['category'] == 'real'].sample(n=500, random_state=42)

# Unir los dos subconjuntos
sample_df = pd.concat([fake_sample, real_sample]).reset_index(drop=True)

# Mostrar el DataFrame resultante
display(sample_df)
# Out:
#            filename category
# 0     fake_3667.png     fake
# 1     fake_5380.png     fake
# 2    fake_22212.png     fake
# 3     fake_4830.png     fake
# 4    fake_19839.png     fake
# ..              ...      ...
# 995  real_16809.png     real
# 996  real_24052.png     real
# 997  real_18268.png     real
# 998  real_13051.png     real
# 999  real_12937.png     real
#
# [1000 rows x 2 columns]

# %%
#ahora metamoslo a una red neuronal

from sklearn.model_selection import train_test_split

#Extracción de DataFrames de entrenamiento y prueba
train_df, test_df = train_test_split(sample_df, test_size = 0.2)

#Revisión de los tamaños de los DataFrames
print("\nEl tamaño del DataFrame de entrada es:", sample_df.shape)
print("El tamaño del DataFrame para entrenamiento es:", train_df.shape)
print("El tamaño del DataFrame para prueba es:", test_df.shape)
# Out:
# El tamaño del DataFrame de entrada es: (1000, 2)
# El tamaño del DataFrame para entrenamiento es: (800, 2)
# El tamaño del DataFrame para prueba es: (200, 2)

# %%
from skimage import io

filename = 'fake_1.png'
predicted = f'./dataset_fake_real/{filename}'
img = io.imread(predicted)

print(img)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.Blowfish and will be removed from this module in 45.0.0.
#   "class": algorithms.Blowfish,
# c:\ProgramData\anaconda3\Lib\site-packages\paramiko\transport.py:243: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,
# [[ 40  41  50 ...   0   0   0]
#  [ 37  46  55 ...   0   0   0]
#  [ 44  52  52 ...   0   0   0]
#  ...
#  [159 171 186 ...   0   0   0]
#  [121 109 161 ...   0   0   0]
#  [183 141 114 ...   0   0   0]]

# %%
#Importación de librerías
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Data augmentation solo en entrenamiento
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=5,
    width_shift_range=0.05,
    height_shift_range=0.05,
    shear_range=0.05,
    zoom_range=0.05,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Solo rescale en validación/test
test_datagen = ImageDataGenerator(rescale=1./255)
#Normalización de las Imágenes ya se realizo
#datagen = ImageDataGenerator()  #

#Generador de Imágenes de Entrenamiento
traingenerator = train_datagen.flow_from_dataframe(train_df , './dataset_fake_real', 
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (128,128),
                                             class_mode='binary', 
                                             color_mode='grayscale',
                                             batch_size = 32,
                                                shuffle=True) # está bien que se barajeen para que el modelo no aprenda el orden
#Generador de Imágenes de Prueba
testgenerator = test_datagen.flow_from_dataframe( test_df , './dataset_fake_real',
                                             x_col = 'filename' , 
                                             y_col = 'category', 
                                             target_size = (128,128),
                                             color_mode='grayscale',
                                             class_mode='binary', 
                                             shuffle=False,
                                             batch_size = 32)
# Out:
# Found 800 validated image filenames belonging to 2 classes.
# Found 200 validated image filenames belonging to 2 classes.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.metrics import AUC
from tensorflow.keras.optimizers import Adam

model = tf.keras.Sequential([
    Conv2D(32, (5, 5), activation='relu', padding='same', input_shape=(128, 128, 1)),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(64, (5, 5), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(128, (5, 5), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Conv2D(256, (5, 5), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),

    Flatten(),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])  

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy', AUC(name='auc')]
)
'''
model = tf.keras.Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(128, 128, 1), padding='same'),
    MaxPooling2D((2,2)),
    
    Conv2D(64, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),
    
    Conv2D(128, (3,3), activation='relu', padding='same'),
    MaxPooling2D((2,2)),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=['accuracy', AUC(name='auc')]
)
'''

#si val los no mejora, lo detiene, espera 7 epocas si no mejora
early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
#reduce la tasa de aprendizaje si no mejora, espera 3 epocas si no mejora
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    traingenerator,
    validation_data=testgenerator,
    epochs=50,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.5519 - auc: 0.5634 - loss: 0.7201 - val_accuracy: 0.4950 - val_auc: 0.5583 - val_loss: 0.6932 - learning_rate: 1.0000e-04
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.5715 - auc: 0.5740 - loss: 0.7152 - val_accuracy: 0.5300 - val_auc: 0.5971 - val_loss: 0.6916 - learning_rate: 1.0000e-04
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.5853 - auc: 0.6100 - loss: 0.6762 - val_accuracy: 0.5100 - val_auc: 0.6381 - val_loss: 0.6908 - learning_rate: 1.0000e-04
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 947ms/step - accuracy: 0.6161 - auc: 0.6589 - loss: 0.6550 - val_accuracy: 0.5050 - val_auc: 0.6091 - val_loss: 0.6912 - learning_rate: 1.0000e-04
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 974ms/step - accuracy: 0.5777 - auc: 0.6269 - loss: 0.6699 - val_accuracy: 0.5700 - val_auc: 0.6000 - val_loss: 0.6903 - learning_rate: 1.0000e-04
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 935ms/step - accuracy: 0.6340 - auc: 0.6749 - loss: 0.6495 - val_accuracy: 0.5150 - val_auc: 0.5913 - val_loss: 0.6902 - learning_rate: 1.0000e-04
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 912ms/step - accuracy: 0.6669 - auc: 0.7205 - loss: 0.6222 - val_accuracy: 0.5200 - val_auc: 0.6706 - val_loss: 0.6876 - learning_rate: 1.0000e-04
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 917ms/step - accuracy: 0.6120 - auc: 0.6462 - loss: 0.6640 - val_accuracy: 0.5450 - val_auc: 0.6271 - val_loss: 0.6875 - learning_rate: 1.0000e-04
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 906ms/step - accuracy: 0.5863 - auc: 0.6351 - loss: 0.6637 - val_accuracy: 0.5050 - val_auc: 0.6356 - val_loss: 0.6883 - learning_rate: 1.0000e-04
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 918ms/step - accuracy: 0.6402 - auc: 0.6716 - loss: 0.6480 - val_accuracy: 0.5100 - val_auc: 0.6633 - val_loss: 0.6856 - learning_rate: 1.0000e-04
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 926ms/step - accuracy: 0.6314 - auc: 0.6858 - loss: 0.6385 - val_accuracy: 0.6050 - val_auc: 0.6604 - val_loss: 0.6814 - learning_rate: 1.0000e-04
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 908ms/step - accuracy: 0.6366 - auc: 0.7243 - loss: 0.6134 - val_accuracy: 0.5050 - val_auc: 0.6371 - val_loss: 0.7247 - learning_rate: 1.0000e-04
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 922ms/step - accuracy: 0.6845 - auc: 0.7351 - loss: 0.6098 - val_accuracy: 0.5950 - val_auc: 0.6606 - val_loss: 0.6786 - learning_rate: 1.0000e-04
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 906ms/step - accuracy: 0.6862 - auc: 0.7513 - loss: 0.5946 - val_accuracy: 0.4950 - val_auc: 0.6439 - val_loss: 0.7164 - learning_rate: 1.0000e-04
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 927ms/step - accuracy: 0.6412 - auc: 0.7113 - loss: 0.6159 - val_accuracy: 0.5250 - val_auc: 0.6706 - val_loss: 0.6815 - learning_rate: 1.0000e-04
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.6874 - auc: 0.7554 - loss: 0.5898 - val_accuracy: 0.5150 - val_auc: 0.6758 - val_loss: 0.6857 - learning_rate: 1.0000e-04
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 912ms/step - accuracy: 0.6820 - auc: 0.7509 - loss: 0.5960 - val_accuracy: 0.5800 - val_auc: 0.7028 - val_loss: 0.6607 - learning_rate: 5.0000e-05
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 881ms/step - accuracy: 0.7113 - auc: 0.7784 - loss: 0.5642 - val_accuracy: 0.5800 - val_auc: 0.7241 - val_loss: 0.6520 - learning_rate: 5.0000e-05
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 869ms/step - accuracy: 0.7228 - auc: 0.7901 - loss: 0.5530 - val_accuracy: 0.6600 - val_auc: 0.7302 - val_loss: 0.6349 - learning_rate: 5.0000e-05
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.7499 - auc: 0.7997 - loss: 0.5515 - val_accuracy: 0.6550 - val_auc: 0.7343 - val_loss: 0.6254 - learning_rate: 5.0000e-05
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 886ms/step - accuracy: 0.7607 - auc: 0.8244 - loss: 0.5243 - val_accuracy: 0.5650 - val_auc: 0.7357 - val_loss: 0.6674 - learning_rate: 5.0000e-05
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 875ms/step - accuracy: 0.7163 - auc: 0.7904 - loss: 0.5534 - val_accuracy: 0.6200 - val_auc: 0.7476 - val_loss: 0.6196 - learning_rate: 5.0000e-05
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 852ms/step - accuracy: 0.7375 - auc: 0.8264 - loss: 0.5235 - val_accuracy: 0.4950 - val_auc: 0.6817 - val_loss: 1.0907 - learning_rate: 5.0000e-05
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 864ms/step - accuracy: 0.7118 - auc: 0.7902 - loss: 0.5585 - val_accuracy: 0.6350 - val_auc: 0.7331 - val_loss: 0.6225 - learning_rate: 5.0000e-05
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 840ms/step - accuracy: 0.7680 - auc: 0.8387 - loss: 0.5005 - val_accuracy: 0.6250 - val_auc: 0.7521 - val_loss: 0.6286 - learning_rate: 5.0000e-05
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 854ms/step - accuracy: 0.7548 - auc: 0.8243 - loss: 0.5173 - val_accuracy: 0.6600 - val_auc: 0.7597 - val_loss: 0.6031 - learning_rate: 2.5000e-05
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 849ms/step - accuracy: 0.7489 - auc: 0.8529 - loss: 0.4813 - val_accuracy: 0.5150 - val_auc: 0.7764 - val_loss: 1.0141 - learning_rate: 2.5000e-05
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 844ms/step - accuracy: 0.7717 - auc: 0.8636 - loss: 0.4722 - val_accuracy: 0.7100 - val_auc: 0.7631 - val_loss: 0.5718 - learning_rate: 2.5000e-05
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 885ms/step - accuracy: 0.7618 - auc: 0.8289 - loss: 0.5100 - val_accuracy: 0.7000 - val_auc: 0.7750 - val_loss: 0.5815 - learning_rate: 2.5000e-05
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.7911 - auc: 0.8544 - loss: 0.4879 - val_accuracy: 0.6300 - val_auc: 0.7744 - val_loss: 0.6374 - learning_rate: 2.5000e-05
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.7649 - auc: 0.8573 - loss: 0.4739 - val_accuracy: 0.6850 - val_auc: 0.7785 - val_loss: 0.5658 - learning_rate: 2.5000e-05
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.8030 - auc: 0.8745 - loss: 0.4524 - val_accuracy: 0.6100 - val_auc: 0.7612 - val_loss: 0.7277 - learning_rate: 2.5000e-05
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7901 - auc: 0.8631 - loss: 0.4731 - val_accuracy: 0.6150 - val_auc: 0.7694 - val_loss: 0.6753 - learning_rate: 2.5000e-05
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.7933 - auc: 0.8669 - loss: 0.4620 - val_accuracy: 0.6150 - val_auc: 0.7522 - val_loss: 0.7071 - learning_rate: 2.5000e-05
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8084 - auc: 0.8828 - loss: 0.4473 - val_accuracy: 0.6900 - val_auc: 0.7711 - val_loss: 0.5656 - learning_rate: 1.2500e-05
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8185 - auc: 0.8955 - loss: 0.4339 - val_accuracy: 0.6150 - val_auc: 0.7819 - val_loss: 0.7457 - learning_rate: 1.2500e-05
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8152 - auc: 0.8942 - loss: 0.4297 - val_accuracy: 0.6900 - val_auc: 0.7874 - val_loss: 0.5788 - learning_rate: 1.2500e-05
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8194 - auc: 0.8898 - loss: 0.4299 - val_accuracy: 0.6650 - val_auc: 0.7867 - val_loss: 0.6141 - learning_rate: 1.2500e-05
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8124 - auc: 0.8995 - loss: 0.4159 - val_accuracy: 0.7050 - val_auc: 0.7867 - val_loss: 0.5530 - learning_rate: 6.2500e-06
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.7934 - auc: 0.8844 - loss: 0.4380 - val_accuracy: 0.7150 - val_auc: 0.7868 - val_loss: 0.5576 - learning_rate: 6.2500e-06
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8204 - auc: 0.8945 - loss: 0.4269 - val_accuracy: 0.7100 - val_auc: 0.7873 - val_loss: 0.5511 - learning_rate: 6.2500e-06
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8195 - auc: 0.8913 - loss: 0.4293 - val_accuracy: 0.6950 - val_auc: 0.7872 - val_loss: 0.5689 - learning_rate: 6.2500e-06
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.8487 - auc: 0.9122 - loss: 0.4020 - val_accuracy: 0.7250 - val_auc: 0.7919 - val_loss: 0.5446 - learning_rate: 6.2500e-06
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.8108 - auc: 0.8876 - loss: 0.4357 - val_accuracy: 0.7200 - val_auc: 0.7883 - val_loss: 0.5529 - learning_rate: 6.2500e-06
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8068 - auc: 0.8931 - loss: 0.4256 - val_accuracy: 0.7100 - val_auc: 0.7902 - val_loss: 0.5545 - learning_rate: 6.2500e-06
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8011 - auc: 0.8971 - loss: 0.4149 - val_accuracy: 0.7300 - val_auc: 0.7892 - val_loss: 0.5577 - learning_rate: 6.2500e-06
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.8056 - auc: 0.8895 - loss: 0.4254 - val_accuracy: 0.7200 - val_auc: 0.7870 - val_loss: 0.5586 - learning_rate: 3.1250e-06
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.7904 - auc: 0.9025 - loss: 0.4201 - val_accuracy: 0.7100 - val_auc: 0.7895 - val_loss: 0.5552 - learning_rate: 3.1250e-06
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.8454 - auc: 0.9245 - loss: 0.3887 - val_accuracy: 0.7150 - val_auc: 0.7894 - val_loss: 0.5510 - learning_rate: 3.1250e-06
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 32s 1s/step - accuracy: 0.8284 - auc: 0.9012 - loss: 0.4167 - val_accuracy: 0.7250 - val_auc: 0.7901 - val_loss: 0.5582 - learning_rate: 1.5625e-06

# %%
#Resumen del entrenamiento por medio de la asertividad (accuracy)
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Training set', 'Test set'], loc='best')
plt.show();

# %%
train_df['category'].value_counts()
# Out:
# category
# fake    401
# real    399
# Name: count, dtype: int64

# %%
#Resumen del entrenamiento por medio de la pérdida (loss)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Nivel de Pérdida del Modelo')
plt.ylabel('Pérdida')
plt.xlabel('Épocas')
plt.legend(['Entrenamiento', 'Prueba'], loc='best')
plt.show();

# %%
#Generar un Diccionario con las Categorías de Clasificación de las Imágenes
traingenerator.class_indices
labels = (traingenerator.class_indices)
labels = dict((v,k) for k,v in labels.items())
print("Las categorías de clasificación de las imágenes son:", labels)
# Out:
# Las categorías de clasificación de las imágenes son: {0: 'fake', 1: 'real'}

# %%
loss, acc, auc = model.evaluate(testgenerator)
print(f"\n✅ Evaluación final:  \nAccuracy: {acc:.4f} AUC: {auc:.4f}")
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 357ms/step - accuracy: 0.7305 - auc: 0.7992 - loss: 0.5313
#
# ✅ Evaluación final:
# Accuracy: 0.7250 AUC: 0.7919

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.transform import resize
from tensorflow.keras.preprocessing import image
import numpy as np
    
#def test_the_model(model, image_path):
    # Cargar imagen
#    img = io.imread(image_path)

    # Verificar número de canales
#    if len(img.shape) == 2:  # Imagen en escala de grises
#        img = np.expand_dims(img, axis=-1)  # Añadir canal extra para forma (128,128,1)

    # Redimensionar y normalizar
#    img = resize(img, (128, 128, 1))  # Asegura forma (128,128,1)
#    img = img / 255.0
#    img = np.reshape(img, (1, 128, 128, 1))  # Para el modelo

    # Predicción
#    prediction = model.predict(img)
#    predicted_class = np.argmax(prediction)

    # Obtener etiquetas
#    labels = (traingenerator.class_indices)
#    labels = dict((v, k) for k, v in labels.items())
#    return labels[predicted_class]

def test_the_model(model, img_path):
    img = image.load_img(img_path, target_size=(128, 128), color_mode='grayscale')
    img_array = image.img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0)  # shape: (1, 128, 128, 1)

    prediction = model.predict(img_array, verbose=0)[0][0]

    return 'fake' if prediction < 0.5 else 'real'  # devuelve la clase como string


filename = 'fake_5.png'
predicted = test_the_model(model, f'./dataset_fake_real/{filename}')

real_category = fake_real[fake_real['filename'] == filename]['category'].values[0]
print(f'Prediction: {predicted}')

print(f'True category: {real_category}')
# Out:
# Prediction: fake
# True category: fake

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# ============================
#  1. Obtener etiquetas y predicciones
# ============================

# Asegúrate que testgenerator tenga shuffle=False
y_true = testgenerator.classes

# Predicciones del modelo (probabilidades)
y_pred_probs = model.predict(testgenerator, verbose=1)

# Convertir a 0 o 1 según umbral 0.5
y_pred = (y_pred_probs > 0.5).astype("int32").reshape(-1)

# ============================
# 2. Reporte de clasificación
# ============================

print("\nReporte de Clasificación:")
print(classification_report(y_true, y_pred, target_names=['fake', 'real']))

# ============================
# 3. Matriz de confusión
# ============================

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['fake', 'real'])

# ============================
#  4. Visualizar la matriz
# ============================

plt.figure(figsize=(6, 5))
disp.plot(cmap=plt.cm.Blues, values_format='d')
plt.title(" Matriz de Confusión")
plt.xlabel("Predicción")
plt.ylabel("Etiqueta Verdadera")
plt.grid(False)
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 340ms/step
#
# Reporte de Clasificación:
#               precision    recall  f1-score   support
#
#         fake       0.72      0.72      0.72        99
#         real       0.73      0.73      0.73       101
#
#     accuracy                           0.72       200
#    macro avg       0.72      0.72      0.72       200
# weighted avg       0.72      0.72      0.72       200
